# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import lda
from sklearn.externals import joblib
import time

# %%
header = ['class_id', 'title', 'description']
train_df = pd.read_csv('../data/db_pedia/train.csv', header=None, names=header)

# %%
train_df.head()
# Out:
#    class_id                              title  \
# 0         1                   E. D. Abbott Ltd
# 1         1                     Schwan-Stabilo
# 2         1                         Q-workshop
# 3         1  Marvell Software Solutions Israel
# 4         1        Bergan Mercy Medical Center
#
#                                          description
# 0   Abbott of Farnham E D Abbott Limited was a Br...
# 1   Schwan-STABILO is a German maker of pens for ...
# 2   Q-workshop is a Polish company located in Poz...
# 3   Marvell Software Solutions Israel known as RA...
# 4   Bergan Mercy Medical Center is a hospital loc...

# %%
train_df.title = train_df.title.str.lower()
train_df.description = train_df.description.str.lower()

# %%
train_x = train_df.title.values + ' ' + train_df.description.values

# %%
bow_model = CountVectorizer(stop_words='english')

# %%
bow = bow_model.fit_transform(train_x)

# %%
bow_model.get_feature_names()[:10]
# Out:
# ['00',
#  '000',
#  '0000',
#  '00000006',
#  '000001',
#  '000002',
#  '00000972',
#  '000012',
#  '000015',
#  '000018']

# %%
joblib.dump(bow_model, '../models/dbpedia_bow_model.pkl')
bow_model = joblib.load('../models/dbpedia_bow_model.pkl')

# %%
bow = bow_model.transform(train_x)

# %%
# n_topics = [20]
n_topics = [100]
# n_topics = [200]
n_iter = 2000

# %%
with open('./dbpedia_topic100iter2000_done_time.txt', 'w') as f:
    for n in n_topics:
        start = time.time()
        lda_model = lda.lda.LDA(n_topics=n, n_iter=n_iter, random_state=0)
        lda_model.fit(bow)
#         joblib.dump(lda_model, '../models/hybrid_lda_model_{}_{}iter.pkl'.format(n, n_iter))
        joblib.dump(lda_model, '../models/dbpedia_lda_model_{}_{}iter.pkl'.format(n, n_iter))
        end = time.time()
        print("topic_N =", str(n), "train time", end - start, file=f)
# Out:
# INFO:lda:n_documents: 560000
# INFO:lda:vocab_size: 671754
# INFO:lda:n_words: 17243036
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 2000
# /home/moriya/chainer2.1.0/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:<10> log likelihood: -185963427
# INFO:lda:<20> log likelihood: -166643540
# INFO:lda:<30> log likelihood: -161749909
# INFO:lda:<40> log likelihood: -159516258
# INFO:lda:<50> log likelihood: -158240453
# INFO:lda:<60> log likelihood: -157440623
# INFO:lda:<70> log likelihood: -156915282
# INFO:lda:<80> log likelihood: -156550047
# INFO:lda:<90> log likelihood: -156293965
# INFO:lda:<100> log likelihood: -156084553
# INFO:lda:<110> log likelihood: -155927969
# INFO:lda:<120> log likelihood: -155795867
# INFO:lda:<130> log likelihood: -155691814
# INFO:lda:<140> log likelihood: -155620747
# INFO:lda:<150> log likelihood: -155542469
# INFO:lda:<160> log likelihood: -155480517
# INFO:lda:<170> log likelihood: -155423854
# INFO:lda:<180> log likelihood: -155367053
# INFO:lda:<190> log likelihood: -155311589
# INFO:lda:<200> log likelihood: -155263973
# INFO:lda:<210> log likelihood: -155222212
# INFO:lda:<220> log likelihood: -155164702
# INFO:lda:<230> log likelihood: -155131882
# INFO:lda:<240> log likelihood: -155102825
# INFO:lda:<250> log likelihood: -155090806
# INFO:lda:<260> log likelihood: -155071398
# INFO:lda:<270> log likelihood: -155053884
# INFO:lda:<280> log likelihood: -155046367
# INFO:lda:<290> log likelihood: -155042896
# INFO:lda:<300> log likelihood: -155022915
# INFO:lda:<310> log likelihood: -155016679
# INFO:lda:<320> log likelihood: -155012558
# INFO:lda:<330> log likelihood: -155007695
# INFO:lda:<340> log likelihood: -154992363
# INFO:lda:<350> log likelihood: -154982113
# INFO:lda:<360> log likelihood: -154982924
# INFO:lda:<370> log likelihood: -154981362
# INFO:lda:<380> log likelihood: -154970771
# INFO:lda:<390> log likelihood: -154969322
# INFO:lda:<400> log likelihood: -154954613
# INFO:lda:<410> log likelihood: -154955424
# INFO:lda:<420> log likelihood: -154953518
# INFO:lda:<430> log likelihood: -154951938
# INFO:lda:<440> log likelihood: -154942283
# INFO:lda:<450> log likelihood: -154945943
# INFO:lda:<460> log likelihood: -154933348
# INFO:lda:<470> log likelihood: -154937707
# INFO:lda:<480> log likelihood: -154922895
# INFO:lda:<490> log likelihood: -154916764
# INFO:lda:<500> log likelihood: -154909051
# INFO:lda:<510> log likelihood: -154907561
# INFO:lda:<520> log likelihood: -154888734
# INFO:lda:<530> log likelihood: -154876611
# INFO:lda:<540> log likelihood: -154878894
# INFO:lda:<550> log likelihood: -154870627
# INFO:lda:<560> log likelihood: -154867805
# INFO:lda:<570> log likelihood: -154862307
# INFO:lda:<580> log likelihood: -154867360
# INFO:lda:<590> log likelihood: -154850428
# INFO:lda:<600> log likelihood: -154845884
# INFO:lda:<610> log likelihood: -154856640
# INFO:lda:<620> log likelihood: -154848104
# INFO:lda:<630> log likelihood: -154845995
# INFO:lda:<640> log likelihood: -154851736
# INFO:lda:<650> log likelihood: -154848601
# INFO:lda:<660> log likelihood: -154841778
# INFO:lda:<670> log likelihood: -154842678
# INFO:lda:<680> log likelihood: -154845442
# INFO:lda:<690> log likelihood: -154847312
# INFO:lda:<700> log likelihood: -154843459
# INFO:lda:<710> log likelihood: -154849450
# INFO:lda:<720> log likelihood: -154838546
# INFO:lda:<730> log likelihood: -154832138
# INFO:lda:<740> log likelihood: -154825008
# INFO:lda:<750> log likelihood: -154827256
# INFO:lda:<760> log likelihood: -154825095
# INFO:lda:<770> log likelihood: -154828503
# INFO:lda:<780> log likelihood: -154835848
# INFO:lda:<790> log likelihood: -154828273
# INFO:lda:<800> log likelihood: -154823418
# INFO:lda:<810> log likelihood: -154819512
# INFO:lda:<820> log likelihood: -154826473
# INFO:lda:<830> log likelihood: -154824552
# INFO:lda:<840> log likelihood: -154823528

# %%
lda_model_100 = joblib.load('../models/dbpedia_lda_model_100_2000iter.pkl')

# %%
feature_names = bow_model.get_feature_names()

# %%
for topic in lda_model_100.components_:
    sorted_index = np.argsort(topic)[::-1]
    top_words = np.array([feature_names[i] for i in sorted_index[:20]])
    print(top_words)
# Out:
# ['book' 'history' 'life' 'written' 'jewish' 'work' 'human' 'israel'
#  'political' 'social' 'world' 'non' 'israeli' 'hebrew' 'synagogue'
#  'published' 'people' 'culture' 'author' 'modern']
# ['class' 'railway' 'built' 'locomotive' 'electric' 'locomotives' 'steam'
#  'railways' 'railroad' 'station' 'diesel' 'line' 'train' 'rail' 'service'
#  'type' 'series' 'used' 'operated' 'unit']
# ['records' 'label' 'record' 'music' 'hop' 'hip' 'independent' 'group'
#  'producer' 'dj' 'rapper' 'based' 'american' 'artists' 'known' 'founded'
#  'artist' 'better' 'released' 'dance']
# ['company' 'air' 'based' 'airline' 'international' 'services' 'airport'
#  'owned' 'power' 'oil' 'bus' 'operates' 'service' 'airlines' 'operated'
#  'energy' 'gas' 'transit' 'main' 'charter']
# ['family' 'republic' 'butterfly' 'congo' 'africa' 'kenya' 'african'
#  'tanzania' 'democratic' 'uganda' 'ghana' 'central' 'cameroon' 'consists'
#  'guinea' 'coast' 'western' 'sierra' 'zimbabwe' 'nigeria']
# ['television' 'born' 'play' 'actor' 'known' 'theatre' 'series' 'actress'
#  'american' 'tv' 'stage' 'best' 'radio' 'appeared' 'singer' 'british'
#  'writer' 'role' 'comedian' 'theater']
# ['mi' 'village' 'km' 'east' 'county' 'poland' 'voivodeship' 'district'
#  'north' 'gmina' 'administrative' 'south' 'west' 'kilometres'
#  'approximately' 'lies' 'central' 'regional' 'capital' 'eastern']
# ['hospital' 'medical' 'health' 'center' 'medicine' 'care' 'non'
#  'organization' 'foundation' 'dr' 'services' 'profit' 'children' 'located'
#  'general' 'cancer' 'founded' 'doctor' 'hospitals' 'healthcare']
# ['film' 'directed' 'written' 'starring' 'drama' 'stars' 'comedy'
#  'festival' 'produced' 'based' 'released' 'documentary' 'movie' 'american'
#  'horror' 'films' 'director' 'feature' 'action' 'international']
# ['species' 'family' 'plant' 'endemic' 'habitat' 'tropical' 'natural'
#  'subtropical' 'forests' 'threatened' 'loss' 'moist' 'ecuador' 'habitats'
#  'montane' 'lowland' 'frog' 'dry' 'malaysia' 'flowering']
# ['novel' 'book' 'published' 'written' 'author' 'series' 'story' 'children'
#  'books' 'writer' 'novels' 'set' 'fiction' 'fantasy' 'young' 'second'
#  'english' 'trilogy' 'title' 'historical']
# ['india' 'indian' 'district' 'state' 'village' 'pradesh' 'karnataka'
#  'kerala' 'tamil' 'delhi' 'nadu' 'sabha' 'government' 'bengal' 'andhra'
#  'singh' 'lok' 'located' 'west' 'mumbai']
# ['class' 'navy' 'ship' 'hms' 'royal' 'built' 'launched' 'ships' 'service'
#  'gun' 'war' 'ss' 'vessel' 'line' 'served' 'british' 'named' 'sold'
#  'renamed' 'frigate']
# ['born' 'footballer' 'football' 'plays' 'played' 'league' 'currently'
#  'club' 'professional' 'player' 'team' 'playing' 'midfielder' 'national'
#  'defender' 'career' 'soccer' 'january' 'fc' 'september']
# ['mountain' 'range' 'mount' 'peak' 'mountains' 'located' 'highest' 'pass'
#  'glacier' 'north' 'summit' 'ft' 'national' 'park' 'metres' 'south' 'alps'
#  'elevation' 'border' 'west']
# ['born' 'english' 'cricketer' 'right' 'played' 'cricket' 'class' 'debut'
#  'handed' 'arm' 'batsman' 'left' 'minor' 'simon' 'test' 'collins' 'evans'
#  'matches' 'fast' 'match']
# ['born' 'summer' 'olympics' 'won' 'world' 'competed' 'medal' 'team' 'gold'
#  'silver' 'championships' 'champion' 'event' 'olympic' 'bronze' 'time'
#  'winter' 'men' 'events' 'national']
# ['river' 'km' 'creek' 'flows' 'long' 'north' 'tributary' 'miles' 'bay'
#  'near' 'south' 'west' 'east' 'mile' 'county' 'source' 'area' 'basin' 'mi'
#  'stream']
# ['uss' 'navy' 'united' 'states' 'class' 'ship' 'war' 'named'
#  'commissioned' 'launched' 'world' 'laid' 'built' '1944' 'ii' 'sponsored'
#  'command' '1943' 'mrs' 'acquired']
# ['chinese' 'china' 'hong' 'kong' 'pinyin' 'traditional' 'taiwan'
#  'singapore' 'republic' 'simplified' 'people' 'shanghai' 'beijing'
#  'province' 'known' 'li' 'chan' 'taiwanese' 'wang' 'chen']
# ['life' 'young' 'man' 'story' 'old' 'love' 'boy' 'good' 'time' 'year'
#  'girl' 'woman' 'way' 'home' 'tells' 'years' 'day' 'father' 'death'
#  'follows']
# ['california' 'san' 'los' 'angeles' 'francisco' 'philippines' 'city'
#  'arizona' 'santa' 'valley' 'nevada' 'diego' 'county' 'known' 'filipino'
#  'phoenix' 'philippine' 'bay' 'hills' 'southern']
# ['family' 'moth' 'species' 'genus' 'described' 'mm' 'wingspan' 'moths'
#  'larvae' 'feed' 'brown' 'arctiidae' 'beetle' 'noctuidae' 'adults'
#  'geometridae' 'forewings' 'wing' 'known' 'tortricidae']
# ['album' 'released' 'live' 'songs' 'band' 'compilation' 'tracks' 'cd' 'ep'
#  'recorded' 'music' 'release' 'records' 'dvd' 'rock' 'contains' 'track'
#  'version' 'studio' 'second']
# ['best' 'award' 'won' 'awards' 'year' 'winning' 'prize' 'nominated'
#  'received' 'academy' 'golden' 'international' '2007' 'grammy' '2008'
#  '2006' 'awarded' '2009' 'short' 'national']
# ['spanish' 'la' 'el' 'mexico' 'mexican' 'puerto' 'spain' 'argentine' 'del'
#  'argentina' 'rico' 'josé' 'juan' 'san' 'chile' 'luis' 'carlos' 'chilean'
#  'colombia' 'latin']
# ['october' 'march' 'december' 'january' 'june' 'september' 'november'
#  'august' 'july' 'february' 'april' '18' '15' '19' '26' 'died' '20' '14'
#  '17' '24']
# ['german' 'germany' 'berlin' 'von' 'austria' 'austrian' 'indonesia' 'die'
#  'der' 'indonesian' 'swiss' 'bavaria' 'rhine' 'switzerland' 'hamburg'
#  'karl' 'saxony' 'westphalia' 'river' 'baden']
# ['nepal' 'sri' 'time' 'lanka' 'extinct' 'living' '1991' 'village' 'zone'
#  'known' 'genus' 'district' 'development' 'population' 'central' 'hawaii'
#  'committee' 'years' 'individual' 'census']
# ['england' 'london' 'english' 'west' 'grade' 'listed' 'british' 'town'
#  'manchester' 'ii' 'hill' 'yorkshire' 'bristol' 'heritage' 'east' 'road'
#  'liverpool' 'north' 'uk' 'borough']
# ['tree' 'known' 'native' 'species' 'plant' 'commonly' 'used' 'family'
#  'small' 'trees' 'common' 'fruit' 'genus' 'wine' 'asia' 'called' 'variety'
#  'wild' 'red' 'names']
# ['school' 'high' 'public' 'district' 'located' 'students' 'schools'
#  'county' 'middle' 'grades' 'serves' '12' 'secondary' 'year' 'elementary'
#  'city' 'township' 'opened' 'principal' 'education']
# ['french' 'france' 'la' 'paris' 'le' 'jean' 'du' 'des' 'les' 'saint'
#  'pierre' 'et' 'louis' 'château' 'english' 'belgian' 'jacques' 'michel'
#  'école' 'marie']
# ['company' 'game' 'video' 'games' 'entertainment' 'based' 'television'
#  'production' 'media' 'founded' 'known' 'radio' 'studio' 'studios' 'space'
#  'films' 'disney' 'tv' 'productions' 'animation']
# ['brazil' 'state' 'brazilian' 'portuguese' 'prison' 'rio' 'da' 'known'
#  'são' 'portugal' 'grande' 'paulo' 'federal' 'silva' 'correctional'
#  'southeastern' 'janeiro' 'dos' 'simply' 'central']
# ['species' 'family' 'genus' 'bird' 'known' 'small' 'long' 'large' 'common'
#  'spider' 'bat' 'birds' 'black' 'yellow' 'subspecies' 'endemic' 'white'
#  'like' 'snake' 'brown']
# ['company' 'group' 'based' 'firm' 'largest' 'business' 'founded'
#  'services' 'financial' 'corporation' 'companies' 'management' 'limited'
#  'international' 'exchange' 'owned' 'headquartered' 'stock' 'investment'
#  'private']
# ['building' 'hotel' 'tower' 'street' 'located' 'city' 'hall' 'office'
#  'built' 'designed' 'completed' 'center' 'library' 'post' 'construction'
#  'downtown' 'tallest' 'known' 'complex' 'skyscraper']
# ['museum' 'village' 'municipality' 'serbian' 'serbia' 'people' '2002'
#  'according' 'population' 'bosnia' 'history' 'herzegovina' 'census'
#  'cyrillic' 'croatian' 'cave' 'croatia' 'located' 'province' 'albania']
# ['ft' 'feet' 'metres' 'long' '20' '30' '10' '50' '100' '40' 'total' '15'
#  '12' '25' 'tall' '60' 'length' '16' '45' 'wide']
# ['irish' 'ireland' 'norwegian' 'norway' 'county' 'danish' 'municipality'
#  'northern' 'dublin' 'village' 'denmark' 'located' 'murphy' 'oslo' 'og'
#  'copenhagen' 'senior' 'cork' 'belfast' 'people']
# ['texas' 'united' 'states' 'county' 'wisconsin' 'tennessee' 'kentucky'
#  'indiana' 'kansas' 'alabama' 'missouri' 'city' 'oklahoma' 'fort'
#  'arkansas' 'mississippi' 'houston' 'state' 'austin' 'usa']
# ['born' 'singer' 'music' 'known' 'musician' 'songwriter' 'band' 'composer'
#  'rock' 'best' 'american' 'guitarist' 'producer' 'member' 'guitar'
#  'musical' 'career' 'pop' 'folk' 'lead']
# ['album' 'band' 'released' 'rock' 'studio' 'metal' 'records' 'second'
#  'debut' 'ep' 'release' 'recorded' 'length' 'punk' 'fourth' 'heavy'
#  'american' 'death' 'produced' 'sound']
# ['swedish' 'dutch' 'van' 'polish' 'netherlands' 'sweden' 'finnish'
#  'finland' 'belgian' 'jan' 'holland' 'stockholm' 'amsterdam' 'belgium'
#  'poland' 'estonian' 'icelandic' 'helsinki' 'iceland' 'den']
# ['published' 'book' 'fiction' 'science' 'series' 'stories' 'short' 'comic'
#  'comics' 'story' 'collection' 'written' 'novel' 'books' 'fantasy'
#  'author' 'edition' 'originally' 'title' 'issue']
# ['church' 'st' 'catholic' 'roman' 'parish' 'saint' 'located' 'mary'
#  'cathedral' 'diocese' 'baptist' 'episcopal' 'john' 'methodist' 'chapel'
#  'holy' 'christian' 'presbyterian' 'paul' 'building']
# ['australian' 'racing' 'grand' 'born' 'year' 'horse' 'road' 'won' 'rules'
#  'race' 'world' 'career' 'driver' 'american' 'time' 'thoroughbred' 'vfl'
#  'british' 'championship' 'victorian']
# ['park' 'located' 'city' 'mall' 'hill' 'centre' 'center' 'area' 'shopping'
#  'road' 'square' 'land' 'opened' 'acres' 'near' 'town' 'largest' 'garden'
#  'm2' 'street']
# ['italian' 'italy' 'di' 'painter' 'rome' 'monte' 'il' 'known' 'milan'
#  'giovanni' 'del' 'la' 'maria' 'san' 'active' 'florence' 'andrea' 'venice'
#  'antonio' 'mainly']
# ['bank' 'thai' 'vietnam' 'national' 'thailand' 'state' 'union'
#  'commercial' 'credit' 'nigerian' 'banks' 'nigeria' 'delta' 'known'
#  'azerbaijani' 'azerbaijan' 'banking' 'branches' 'vietnamese' 'province']
# ['al' 'arabic' 'pakistan' 'bangladesh' 'ali' 'malaysia' 'arab' 'mosque'
#  'jordan' 'khan' 'iranian' 'islamic' 'egyptian' 'urdu' 'egypt' 'known'
#  'el' 'saudi' 'ahmed' 'pakistani']
# ['lake' 'water' 'located' 'area' 'reservoir' 'lakes' 'dam' 'county'
#  'surface' 'north' 'pond' 'park' 'small' 'near' 'utah' 'national' 'km'
#  'km²' 'forest' 'largest']
# ['russian' 'soviet' 'russia' 'ukrainian' 'moscow' 'fc' 'ukraine'
#  'bulgarian' 'union' 'second' 'petersburg' 'oblast' 'alexander' 'georgian'
#  'vladimir' 'ivan' 'division' 'latvia' 'latvian' 'belarusian']
# ['south' 'north' 'america' 'carolina' 'african' 'africa' 'east' 'west'
#  'cape' 'central' 'eastern' 'europe' 'southern' 'dakota' 'asia' 'western'
#  'coast' 'northern' 'known' 'including']
# ['massachusetts' 'michigan' 'illinois' 'chicago' 'united' 'states' 'new'
#  'connecticut' 'boston' 'maine' 'american' 'hampshire' 'lincoln' 'adams'
#  'state' 'detroit' 'vermont' 'city' 'town' 'warren']
# ['paul' 'martin' 'peter' 'czech' 'republic' 'daniel' '1972' '1969' '1971'
#  '1979' '1977' '1967' '1970' '1978' '1974' '1968' 'region' '1980' '1975'
#  '1973']
# ['thomas' 'american' 'john' 'richard' 'david' 'taylor' 'tom' 'scott'
#  'james' 'allen' 'anderson' 'wright' 'walker' 'russell' 'william'
#  'campbell' 'baker' 'cooper' 'ward' 'known']
# ['women' 'american' 'queen' 'wilson' 'mary' 'wife' 'elizabeth' 'lady'
#  'daughter' 'sister' 'mother' 'married' 'anne' 'female' 'children' 'rose'
#  'woman' 'ann' 'banksia' 'jane']
# ['historic' 'house' 'national' 'built' 'register' 'places' 'located'
#  'county' 'listed' 'building' 'story' 'added' 'style' 'home' 'street'
#  'district' 'revival' 'brick' 'bridge' 'stone']
# ['university' 'college' 'institute' 'education' 'located' 'technology'
#  'campus' 'engineering' 'state' 'arts' 'school' 'founded' 'established'
#  'private' 'degree' 'students' 'science' 'institution' 'public' 'law']
# ['genus' 'species' 'family' 'plants' 'bulbophyllum' 'orchid' 'flowering'
#  'endemic' 'plant' 'native' 'brazil' 'tillandsia' 'subfamily' 'contains'
#  'daisy' 'genera' 'grass' 'tribe' 'belongs' 'fabaceae']
# ['rugby' 'south' 'korean' 'union' 'born' 'player' 'korea' 'professional'
#  'club' 'world' 'league' 'tennis' 'tour' 'kim' 'international' 'level'
#  'played' 'playing' 'hangul' 'number']
# ['major' 'baseball' 'league' 'pennsylvania' 'played' 'born' 'american'
#  'philadelphia' 'professional' 'pitcher' 'pittsburgh' 'johnson' 'career'
#  'player' 'louis' 'right' 'september' 'season' 'handed' 'seasons']
# ['art' 'born' 'artist' 'writer' 'known' 'american' 'work' 'poet' 'works'
#  'painter' 'arts' 'author' 'poetry' 'literature' 'novelist' 'literary'
#  'best' 'contemporary' 'fine' 'gallery']
# ['british' 'scottish' 'scotland' 'john' 'sir' 'george' 'lord' '1st'
#  'alexander' 'baron' 'william' 'pc' 'earl' 'robert' 'known' 'james'
#  'hamilton' 'gordon' 'duke' 'loch']
# ['crater' 'located' 'moon' 'rim' 'small' 'lies' 'volcano' 'lunar' 'north'
#  'far' 'south' 'edge' 'west' 'east' 'named' 'southeast' 'impact' 'region'
#  'southern' 'northeast']
# ['film' 'directed' 'indian' 'lead' 'roles' 'tamil' 'produced' 'stars'
#  'starring' 'released' 'malayalam' 'movie' 'hindi' 'language' 'english'
#  'telugu' 'written' 'bollywood' 'music' 'role']
# ['mi' 'village' 'west' 'poland' 'km' 'county' 'voivodeship' 'east' 'north'
#  'south' 'district' 'kilometres' 'administrative' 'gmina' 'approximately'
#  'lies' 'capital' 'regional' '1945' 'history']
# ['journal' 'research' 'published' 'peer' 'reviewed' 'society' 'university'
#  'academic' 'established' 'science' 'scientific' 'international' 'studies'
#  'editor' 'chief' 'field' 'review' 'association' 'covering' 'covers']
# ['magazine' 'newspaper' 'published' 'news' 'daily' 'weekly' 'times'
#  'founded' 'media' 'paper' 'publishing' 'press' 'publication' 'editor'
#  'monthly' 'language' 'based' 'owned' 'english' 'publisher']
# ['album' 'jazz' 'american' 'recorded' 'released' 'jones' 'label' 'blues'
#  'davis' 'bob' 'joe' 'john' 'live' 'featuring' 'saxophonist' 'nelson'
#  'features' 'carter' 'pianist' 'don']
# ['politician' 'member' 'born' 'minister' 'party' 'served' 'national'
#  'elected' 'assembly' 'parliament' 'president' 'prime' 'election' 'leader'
#  'hungarian' 'constituency' 'government' '2010' '2011' 'council']
# ['album' 'released' 'studio' 'singer' 'music' 'single' 'records' 'country'
#  'chart' 'number' 'debut' 'singles' 'billboard' 'albums' 'second' 'love'
#  'american' 'hit' 'songs' 'song']
# ['car' 'produced' 'model' 'ford' 'motor' 'engine' 'automobile' 'cars'
#  'company' 'built' 'series' 'introduced' 'vehicle' 'production'
#  'manufacturer' 'manufactured' 'honda' 'motors' 'door' 'sold']
# ['william' 'john' 'politician' 'henry' 'served' 'born' 'son' 'george'
#  'charles' 'james' 'december' 'governor' 'january' 'october' 'march'
#  'august' 'april' 'february' 'november' 'september']
# ['canada' 'canadian' 'ontario' 'columbia' 'quebec' 'british' 'toronto'
#  'alberta' 'montreal' 'nova' 'vancouver' 'scotia' 'manitoba'
#  'saskatchewan' 'provincial' 'ottawa' 'brunswick' 'assembly' 'saint'
#  'legislative']
# ['war' 'world' 'ii' 'german' 'submarine' 'army' 'military' 'boat' 'type'
#  'battle' 'imperial' 'second' '1942' '1941' 'civil' '1940' 'service'
#  'navy' '1943' 'japanese']
# ['needed' 'citation' 'com' 'free' 'online' 'website' 'million' 'project'
#  '2011' 'based' '2012' '2009' '2010' 'service' '2008' '2013' 'site'
#  'social' 'available' 'web']
# ['century' 'early' 'castle' 'late' '19th' '20th' 'mid' 'site' 'temple'
#  'great' 'known' '18th' 'old' 'years' 'built' 'period' 'fox' 'present'
#  'fort' 'palace']
# ['company' 'founded' 'chain' 'based' 'restaurant' 'store' 'stores' 'food'
#  'brand' 'owned' 'products' 'manufacturer' 'largest' 'brewery' 'retail'
#  'group' 'factory' 'known' 'clothing' 'business']
# ['island' 'king' 'smith' 'turkey' 'province' 'village' 'district'
#  'turkish' 'prince' 'rhode' '2010' 'people' 'armenian' 'population' 'adam'
#  'edward' 'providence' '2011' 'istanbul' 'empire']
# ['member' 'house' 'district' 'politician' 'representatives' 'born' 'state'
#  'republican' 'served' 'democratic' 'senate' 'representing' 'american'
#  'elected' 'january' 'party' 'governor' 'county' 'election' '2013']
# ['river' 'romania' 'tributary' 'valea' 'romanian' 'mare' 'pârâul' 'râul'
#  'hungarian' 'headwater' 'izvorul' 'olt' 'bucharest' 'mic' 'lui' 'moldova'
#  'junction' 'basin' 'mică' 'headwaters']
# ['aircraft' 'designed' 'built' 'single' 'air' 'seat' 'wing' 'produced'
#  'engine' 'design' 'developed' 'fighter' 'light' 'force' 'flying'
#  'biplane' 'monoplane' 'twin' 'aviation' 'construction']
# ['president' 'born' 'general' 'served' 'court' 'united' 'chief' 'law'
#  'states' 'judge' 'secretary' 'director' 'justice' 'office' 'appointed'
#  'governor' 'police' 'officer' 'department' 'july']
# ['new' 'australia' 'australian' 'zealand' 'south' 'western' 'wales'
#  'victoria' 'queensland' 'sydney' 'melbourne' 'island' 'estonia'
#  'northern' 'parish' 'region' 'coast' 'tasmania' 'eastern' 'brisbane']
# ['john' 'american' 'williams' 'lee' 'brown' 'michael' 'james' 'miller'
#  'jackson' 'robert' 'lewis' 'jack' 'moore' 'clark' 'david' 'morgan'
#  'howard' 'kelly' 'ross' 'barry']
# ['greek' 'meaning' 'known' 'wales' 'word' 'latin' 'islands' 'greece'
#  'english' 'means' 'welsh' 'language' 'derived' 'ancient' 'virgin'
#  'specific' 'comes' 'refers' 'diamond' 'alaska']
# ['football' 'born' 'played' 'american' 'league' 'hockey' 'player'
#  'professional' 'national' 'ice' 'basketball' 'college' 'currently'
#  'university' 'draft' 'round' 'nfl' 'team' 'free' 'seasons']
# ['species' 'plant' 'known' 'native' 'common' 'leaves' 'family' 'grows'
#  'flowering' 'flowers' 'long' 'perennial' 'cm' 'tall' 'growing' 'western'
#  'shrub' 'california' 'endemic' 'herb']
# ['black' 'white' 'red' 'blue' 'green' 'little' 'big' 'star' 'known' 'sun'
#  'thompson' 'sky' 'eagle' 'eye' 'gray' 'cross' 'cat' 'light' 'dog' 'tiger']
# ['united' 'states' 'florida' 'ohio' 'washington' 'county' 'virginia'
#  'oregon' 'georgia' 'maryland' 'kingdom' 'state' 'iowa' 'nebraska'
#  'portland' 'west' 'colorado' 'miami' 'baltimore' 'beach']
# ['film' 'directed' 'starring' 'american' 'based' 'comedy' 'silent' 'drama'
#  'british' 'produced' 'play' 'short' 'novel' 'stars' 'written' 'pictures'
#  'lost' 'george' 'released' 'robert']
# ['district' 'village' 'population' '2006' 'rural' 'iran' 'census' 'county'
#  'province' 'persian' 'romanized' 'families' 'central' 'known' 'ye'
#  'reported' 'existence' 'noted' 'khorasan' 'kerman']
# ['school' 'college' 'academy' 'secondary' 'located' 'students' 'girls'
#  'schools' 'high' 'education' 'educational' 'boys' 'founded' 'day'
#  'private' 'christian' 'primary' 'independent' 'international' '12']
# ['company' 'based' 'software' 'systems' 'technology' 'services' 'products'
#  'founded' 'mobile' 'corporation' 'management' 'headquartered' 'solutions'
#  'service' 'business' 'technologies' 'provides' 'information' 'data'
#  'development']
# ['japanese' 'japan' 'manga' 'series' 'tokyo' 'anime' 'prefecture'
#  'written' 'illustrated' 'magazine' 'serialized' 'volumes' 'lit'
#  'released' 'shōnen' 'march' 'kabushiki' 'april' 'known' 'junior']
# ['new' 'york' 'city' 'jersey' 'brooklyn' 'manhattan' 'following' 'orleans'
#  'hudson' 'buffalo' 'containing' 'rochester' 'beetles' 'albany' 'bates'
#  'queens' 'newark' 'ny' 'bronx' 'camden']
# ['species' 'family' 'sea' 'marine' 'gastropod' 'snail' 'mollusk' 'genus'
#  'snails' 'fish' 'ocean' 'pacific' 'land' 'length' 'small' 'allies'
#  'endemic' 'mollusks' 'known' 'ray']

# %%
bow = bow_model.transform(train_x)
theta_docs_100 = lda_model_100.transform(bow)
# Out:
# /home/moriya/chainer2.1.0/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):

# %%
topic_100_df = pd.DataFrame(theta_docs_100)

topic_100_df.columns = ['topic' + str(i) for i in range(100)]

pd.concat([train_df, topic_100_df], axis=1).to_csv('../data/db_pedia/topic100_train.csv', index=False)

# %%
test_df = pd.read_csv('../data/db_pedia/test.csv', header=None, names=header)

test_df.title = test_df.title.str.lower()
test_df.description = test_df.description.str.lower()

test_x = test_df.title.values + ' ' + test_df.description.values

# %%
bow = bow_model.transform(test_x)
theta_docs_100 = lda_model_100.transform(bow)
# Out:
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# /home/moriya/chainer2.1.0/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):

# %%
topic_100_df = pd.DataFrame(theta_docs_100)

topic_100_df.columns = ['topic' + str(i) for i in range(100)]

pd.concat([test_df, topic_100_df], axis=1).to_csv('../data/db_pedia/topic100_test.csv', index=False)
